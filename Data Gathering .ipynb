# %%
import os
os.getcwd() # this is a comment, Python will not pay attention to this.
# Out:
# 'C:\\Users\\John\\Documents\\542'

# %%
cloudLocation_AllMyFiles='https://github.com/jsalber/542/raw/main/Data%20Gathering/'

linkToSTATA_File=cloudLocation_AllMyFiles+'hsb_ok.dta' # '+' concatenates text.
linkToSPSS_File=cloudLocation_AllMyFiles+'hsb_ok.sav'
linkToEXCEL_File=cloudLocation_AllMyFiles+'hsb_ok.xlsx'

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.3.4
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\users\john\anaconda3\lib\site-packages
# Requires: python-dateutil, numpy, pytz
# Required-by: statsmodels, seaborn

# %%
# !pip show xlrd
# Out:
# Name: xlrd
# Version: 2.0.1
# Summary: Library for developers to extract data from Microsoft Excel (tm) .xls spreadsheet files
# Home-page: http://www.python-excel.org/
# Author: Chris Withers
# Author-email: chris@withers.org
# License: BSD
# Location: c:\users\john\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
import pandas as pd # activating pandas

dfStata=pd.read_stata(linkToSTATA_File)
dfExcel=pd.read_excel(linkToEXCEL_File,usecols='B:P') #this omits first column (row number from Excel).

#you can also use:

# import pandas
# dfStata=pandas.read_stata(linkToSTATA_File)
# dfExcel=pandas.read_excel(linkToEXCEL_File)

# %%
type(dfStata) , type(dfExcel)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
dfStata.shape, dfExcel.shape
# Out:
# ((600, 15), (600, 15))

# %%
dfStata.head()
# Out:
#       id     sex   race     ses   sctyp                   hsp  locus  concpt  \
# 0      1  Female  Asian     Low  Public  Vocational/Technical   0.29    0.88
# 1      2    Male  Asian     Low  Public  Academic preparatory  -0.42    0.03
# 2      3  Female  Asian     Low  Public  Academic preparatory   0.71    0.03
# 3      4  Female  Asian  Medium  Public  Vocational/Technical   0.06    0.03
# 4      5  Female  Asian  Medium  Public  Vocational/Technical   0.22   -0.28
#
#     mot             car   rdg  wrtg  math   sci   civ
# 0  0.67  Professional_2  33.6  43.7  40.2  39.0  40.6
# 1  0.33       Craftsman  46.9  35.9  41.9  36.3  45.6
# 2  0.67  Professional_1  41.6  59.3  41.9  44.4  45.6
# 3  0.00         Service  38.9  41.1  32.7  41.7  40.6
# 4  0.00        Clerical  36.3  48.9  39.5  41.7  45.6

# %%
dfExcel.tail()
#?pd.read_excel
# Out:
#       id     sex      race     ses    sctyp      hsp  locus  concpt   mot  \
# 595  596    Male  Hispanic    High  Private  General   0.27   -1.05  0.33
# 596  597    Male  Hispanic  Medium  Private  General   0.55    0.34  1.00
# 597  598    Male  Hispanic  Medium  Private  General  -0.61    0.34  0.67
# 598  599  Female  Hispanic  Medium  Private  General   0.23    0.94  1.00
# 599  600    Male  Hispanic  Medium  Private  General   0.02    0.03  0.33
#
#                 car   rdg  wrtg  math   sci   civ
# 595  Professional_1  60.1  54.1  56.3  55.3  55.6
# 596       Technical  62.7  61.9  72.9  63.4  55.6
# 597       Technical  68.0  54.1  74.6  66.1  65.5
# 598  Professional_2  57.4  67.1  57.9  60.7  55.6
# 599  Professional_1  62.7  54.1  64.7  58.0  50.6

# %%
fileXLSXs=cloudLocation_AllMyFiles+'WA_COVID19_Cases_Hospitalizations_Deaths.xlsx'

#opening each in a different data frame.
dataExcelCovidCases=pd.read_excel(fileXLSXs,sheet_name='Cases')
dataExcelCovidDeaths=pd.read_excel(fileXLSXs,sheet_name='Deaths') 
dataExcelCovidHospitalizations=pd.read_excel(fileXLSXs,sheet_name='Hospitalizations') 
dataExcelCovidDataDictionary=pd.read_excel(fileXLSXs,sheet_name='Data Dictionary')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7292/140341899.py in <module>
#       2
#       3 #opening each in a different data frame.
# ----> 4 dataExcelCovidCases=pd.read_excel(fileXLSXs,sheet_name='Cases')
#       5 dataExcelCovidDeaths=pd.read_excel(fileXLSXs,sheet_name='Deaths')
#       6 dataExcelCovidHospitalizations=pd.read_excel(fileXLSXs,sheet_name='Hospitalizations')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
from IPython.display import IFrame  
fromAPI="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj" 
IFrame(fromAPI, width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\john\anaconda3\lib\site-packages (from sodapy) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\john\anaconda3\lib\site-packages (from requests>=2.20.0->sodapy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\john\anaconda3\lib\site-packages (from requests>=2.20.0->sodapy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\john\anaconda3\lib\site-packages (from requests>=2.20.0->sodapy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\john\anaconda3\lib\site-packages (from requests>=2.20.0->sodapy) (2.0.4)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0

# %%
from sodapy import Socrata

# Unauthenticated client (using 'None')

client = Socrata("data.seattle.gov", None)

# If you have credentials:
# client = Socrata(data.seattle.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 500 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("kzjm-xkqj", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#                        address                        type  \
# 0                 1924 9th Ave                Aid Response
# 1              2320 E UNION ST                Aid Response
# 2             1104 Nw 130th St                Aid Response
# 3       4755 Fauntleroy Way Sw                Aid Response
# 4                627 4th Ave W                Aid Response
# ...                        ...                         ...
# 1995  Nw 85th St / 24th Ave Nw            Triaged Incident
# 1996          7019 47th Ave Sw                Aid Response
# 1997    7122 Fauntleroy Way Sw          Electrical Problem
# 1998          660 W Olympic Pl                Aid Response
# 1999   17th Ave / E Madison St  Medic Response- 6 per Rule
#
#                      datetime   latitude    longitude  \
# 0     2022-01-13T09:41:00.000  47.615796  -122.334741
# 1     2022-01-13T09:32:00.000  47.612941   -122.30244
# 2     2022-01-13T09:31:00.000  47.723312  -122.370418
# 3     2022-01-13T09:30:00.000  47.560074  -122.381457
# 4     2022-01-13T09:29:00.000  47.624935  -122.361932
# ...                       ...        ...          ...
# 1995  2022-01-07T09:35:00.000  47.690575  -122.387598
# 1996  2022-01-07T09:33:00.000  47.540061  -122.393071
# 1997  2022-01-07T09:27:00.000  47.539443  -122.390805
# 1998  2022-01-07T09:27:00.000   47.62781  -122.366435
# 1999  2022-01-07T09:22:00.000   47.61559  -122.310151
#
#                                         report_location incident_number  \
# 0     {'type': 'Point', 'coordinates': [-122.334741,...      F220005633
# 1     {'type': 'Point', 'coordinates': [-122.30244, ...      F220005631
# 2     {'type': 'Point', 'coordinates': [-122.370418,...      F220005630
# 3     {'type': 'Point', 'coordinates': [-122.381457,...      F220005629
# 4     {'type': 'Point', 'coordinates': [-122.361932,...      F220005628
# ...                                                 ...             ...
# 1995  {'type': 'Point', 'coordinates': [-122.387598,...      F220003010
# 1996  {'type': 'Point', 'coordinates': [-122.393071,...      F220003008
# 1997  {'type': 'Point', 'coordinates': [-122.390805,...      F220003007
# 1998  {'type': 'Point', 'coordinates': [-122.366435,...      F220003006
# 1999  {'type': 'Point', 'coordinates': [-122.310151,...      F220003003
#
#      :@computed_region_ru88_fbhk :@computed_region_kuhn_3gp2  \
# 0                             56                          31
# 1                              9                           8
# 2                              6                          32
# 3                              1                          50
# 4                             50                          40
# ...                          ...                         ...
# 1995                           3                          23
# 1996                          37                          51
# 1997                          37                          51
# 1998                          50                          39
# 1999                           9                           6
#
#      :@computed_region_q256_3sug :@computed_region_2day_rhn5  \
# 0                          18081                         NaN
# 1                          19578                         NaN
# 2                          18229                         126
# 3                          19581                         NaN
# 4                          19575                         NaN
# ...                          ...                         ...
# 1995                       18798                         131
# 1996                       17916                         NaN
# 1997                       17916                         NaN
# 1998                       19575                         NaN
# 1999                       19578                         NaN
#
#      :@computed_region_cyqu_gs94
# 0                            NaN
# 1                            NaN
# 2                              1
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         NaN
# 1997                         NaN
# 1998                         NaN
# 1999                         NaN
#
# [2000 rows x 12 columns]

# %%
# !pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.1.4-cp39-cp39-win_amd64.whl (1.3 MB)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\john\anaconda3\lib\site-packages (from pyreadstat) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\john\anaconda3\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\john\anaconda3\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\john\anaconda3\lib\site-packages (from pandas>=1.2.0->pyreadstat) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\john\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyreadstat) (1.16.0)
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.1.4

# %%
# to open link:
from urllib.request import urlopen

response = urlopen(linkToSPSS_File) 

# reading contents
content = response.read() 

# opening a file new file locally
fhandle = open('savingLocally.sav', 'wb') #wb?

# saving contents in that file
fhandle.write(content) 

# closing the file
fhandle.close()

# %%
dataSPSS= pd.read_spss("savingLocally.sav")

# here it is
dataSPSS
# Out:
#         ID     SEX      RACE     SES    SCTYP                   HSP  LOCUS  \
# 0        1  Female     Asian     Low   Public  Vocational/Technical   0.29
# 1        2    Male     Asian     Low   Public  Academic preparatory  -0.42
# 2        3  Female     Asian     Low   Public  Academic preparatory   0.71
# 3        4  Female     Asian  Medium   Public  Vocational/Technical   0.06
# 4        5  Female     Asian  Medium   Public  Vocational/Technical   0.22
# ..     ...     ...       ...     ...      ...                   ...    ...
# 595    596    Male  Hispanic    High  Private               General   0.27
# 596    597    Male  Hispanic  Medium  Private               General   0.55
# 597    598    Male  Hispanic  Medium  Private               General  -0.61
# 598    599  Female  Hispanic  Medium  Private               General   0.23
# 599    600    Male  Hispanic  Medium  Private               General   0.02
#
#      CONCPT   MOT             CAR   RDG  WRTG  MATH   SCI   CIV
# 0      0.88  0.67  Professional_2  33.6  43.7  40.2  39.0  40.6
# 1      0.03  0.33       Craftsman  46.9  35.9  41.9  36.3  45.6
# 2      0.03  0.67  Professional_1  41.6  59.3  41.9  44.4  45.6
# 3      0.03  0.00         Service  38.9  41.1  32.7  41.7  40.6
# 4     -0.28  0.00        Clerical  36.3  48.9  39.5  41.7  45.6
# ..      ...   ...             ...   ...   ...   ...   ...   ...
# 595   -1.05  0.33  Professional_1  60.1  54.1  56.3  55.3  55.6
# 596    0.34  1.00       Technical  62.7  61.9  72.9  63.4  55.6
# 597    0.34  0.67       Technical  68.0  54.1  74.6  66.1  65.5
# 598    0.94  1.00  Professional_2  57.4  67.1  57.9  60.7  55.6
# 599    0.03  0.33  Professional_1  62.7  54.1  64.7  58.0  50.6
#
# [600 rows x 15 columns]

# %%
cloudLocation_AllMyFiles='https://github.com/EvansDataScience/data/raw/master/'

# %%
fileXLSXs=cloudLocation_AllMyFiles+'WA_COVID19_Cases_Hospitalizations_Deaths.xlsx'

#opening each in a different data frame.
dataExcelCovidCases=pd.read_excel(fileXLSXs,sheet_name='Cases')
dataExcelCovidDeaths=pd.read_excel(fileXLSXs,sheet_name='Deaths') 
dataExcelCovidHospitalizations=pd.read_excel(fileXLSXs,sheet_name='Hospitalizations') 
dataExcelCovidDataDictionary=pd.read_excel(fileXLSXs,sheet_name='Data Dictionary')

# %%
dataExcelCovidDataDictionary
# Out:
#                                         Variable.Name  \
# 0                                              County
# 1                                       WeekStartDate
# 2                                       ProbableCases
# 3                                      ConfirmedCases
# 4                                          TotalCases
# 5                                    Hospitalizations
# 6                                              Deaths
# 7                                            Age 0-11
# 8                                           Age 12-19
# 9                                           Age 20-34
# 10                                          Age 35-49
# 11                                          Age 50-64
# 12                                          Age 65-79
# 13                                            Age 80+
# 14                                         UnknownAge
# 15                                        dtm_updated
# 16  *Please note that data are dynamic, so there w...
#
#                                            Definition
# 0                                 County of residence
# 1   This date indicates the first day of the week....
# 2   Number of probable cases with a specimen colle...
# 3   Number of confirmed cases with a specimen coll...
# 4   Number of confirmed and probable cases with a ...
# 5   Number of hospitalizations among confirmed and...
# 6   Number of deaths among confirmed and probable ...
# 7   Number of confirmed and probable cases, hospit...
# 8   Number of confirmed and probable cases, hospit...
# 9   Number of confirmed and probable cases, hospit...
# 10  Number of confirmed and probable cases, hospit...
# 11  Number of confirmed and probable cases, hospit...
# 12  Number of confirmed and probable cases, hospit...
# 13  Number of confirmed and probable cases, hospit...
# 14  Number of confirmed and probable cases, hospit...
# 15  The date and time the data were pulled from th...
# 16                                                NaN

# %%
# if you need more space:
pd.set_option('max_colwidth', 800)
dataExcelCovidDataDictionary
# Out:
#                                                                                           Variable.Name  \
# 0                                                                                                County
# 1                                                                                         WeekStartDate
# 2                                                                                         ProbableCases
# 3                                                                                        ConfirmedCases
# 4                                                                                            TotalCases
# 5                                                                                      Hospitalizations
# 6                                                                                                Deaths
# 7                                                                                              Age 0-11
# 8                                                                                             Age 12-19
# 9                                                                                             Age 20-34
# 10                                                                                            Age 35-49
# 11                                                                                            Age 50-64
# 12                                                                                            Age 65-79
# 13                                                                                              Age 80+
# 14                                                                                           UnknownAge
# 15                                                                                          dtm_updated
# 16  *Please note that data are dynamic, so there will be changes over time as we learn more about cases
#
#                                                                                                                                                                                                                                                                                                                                                                                    Definition
# 0                                                                                                                                                                                                                                                                                                                                                                         County of residence
# 1                                                                                                                                                                                                                                                                                                    This date indicates the first day of the week. Weeks are defined as Sunday to Saturday.
# 2   Number of probable cases with a specimen collection date during that week. Probable cases are individuals with a positive antigen test for COVID-19 and no positive molecular test. The case classification can change to confirmed based on subsequent testing. The case is recorded to the week with the earliest specimen collection date of a positive test, regardless of test type.
# 3                                                                                                            Number of confirmed cases with a specimen collection date during that week. Confirmed cases are individuals with a positive molecular test for COVID-19. The case is recoded to the week with the earliest specimen collection date of a positive test, regardless of test type.
# 4                                                   Number of confirmed and probable cases with a specimen collection date. The case is recorded to the day with the earliest specimen collection date of a positive test, regardless of test type. The 14-day case rate is calculated as the sum of total cases over the past 14 days divided by the population, then multiplied by 100,000.
# 5                                                                                                                                               Number of hospitalizations among confirmed and probable cases with an admission date. The 7-day hospitalization rate is calculated as the sum of hospitalizations over the past 7 days divided by the population, then multiplied by 100,000.
# 6                                           Number of deaths among confirmed and probable cases with a specimen collection date. The death is recorded to the day with the earliest specimen collection date of a positive test, regardless of test type. The 7-day death rate is calculated as the sum of deaths over the past 7 days divided by the population, then multiplied by 100,000.
# 7                                                                                                                                                                                                                                                                                          Number of confirmed and probable cases, hospitalizations, or deaths among those aged 0 to 11 years
# 8                                                                                                                                                                                                                                                                                         Number of confirmed and probable cases, hospitalizations, or deaths among those aged 12 to 19 years
# 9                                                                                                                                                                                                                                                                                         Number of confirmed and probable cases, hospitalizations, or deaths among those aged 20 to 34 years
# 10                                                                                                                                                                                                                                                                                        Number of confirmed and probable cases, hospitalizations, or deaths among those aged 35 to 49 years
# 11                                                                                                                                                                                                                                                                                        Number of confirmed and probable cases, hospitalizations, or deaths among those aged 50 to 64 years
# 12                                                                                                                                                                                                                                                                                        Number of confirmed and probable cases, hospitalizations, or deaths among those aged 65 to 79 years
# 13                                                                                                                                                                                                                                                                                     Number of confirmed and probable cases, hospitalizations, or deaths among those aged 80 years or older
# 14                                                                                                                                                                                                                                                                                        Number of confirmed and probable cases, hospitalizations, or deaths among those with an unknown age
# 15                                                                                                                                                                                                                                                                                                        The date and time the data were pulled from the Washington Disease Reporting System
# 16                                                                                                                                                                                                                                                                                                                                                                                        NaN

# %%
from IPython.display import IFrame  
fromAPI="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj" 
IFrame(fromAPI, width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://dev.socrata.com/foundry/data.seattle.gov/kzjm-xkqj"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame  
wikiLink="https://en.wikipedia.org/wiki/Democracy_Index" 
IFrame(wikiLink, width=700, height=300)
# Out:
#         <iframe
#             width="700"
#             height="300"
#             src="https://en.wikipedia.org/wiki/Democracy_Index"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip show html5lib
# Out:
# Name: html5lib
# Version: 1.1
# Summary: HTML parser based on the WHATWG HTML specification
# Home-page: https://github.com/html5lib/html5lib-python
# Author:
# Author-email:
# License: MIT License
# Location: c:\users\john\anaconda3\lib\site-packages
# Requires: webencodings, six
# Required-by:

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.10.0
# Summary: Screen-scraping library
# Home-page: http://www.crummy.com/software/BeautifulSoup/bs4/
# Author: Leonard Richardson
# Author-email: leonardr@segfault.org
# License: MIT
# Location: c:\users\john\anaconda3\lib\site-packages
# Requires: soupsieve
# Required-by: conda-build

# %%
# !pip show lxml
# Out:
# Name: lxml
# Version: 4.6.3
# Summary: Powerful and Pythonic XML processing library combining libxml2/libxslt with the ElementTree API.
# Home-page: https://lxml.de/
# Author: lxml dev team
# Author-email: lxml-dev@lxml.de
# License: BSD
# Location: c:\users\john\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
dataWIKI=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable'})

# %%
type(dataWIKI)
# Out:
# list

# %%
len(dataWIKI)
# Out:
# 6

# %%
# remember that Python starts counting in ZERO!
dataWIKI[0]
# Out:
#           Type of regime  Colors  Colors.1    Score  Countries Countries (%)  \
# 0       Full democracies     NaN       NaN  8.01–10         23         13.8%
# 1     Flawed democracies     NaN       NaN   6.01–8         52         31.1%
# 2         Hybrid regimes     NaN       NaN   4.01–6         35         21.0%
# 3  Authoritarian regimes     NaN       NaN      0–4         57         34.1%
#
#   World population (%) GDP (%)
# 0                 8.4%   27.5%
# 1                41.0%   45.7%
# 2                15.0%    3.7%
# 3                35.6%   23.1%

# %%
dataWIKI[5]
# Out:
#                  Rank  \
# 0    Full democracies
# 1                   1
# 2                   2
# 3                   3
# 4                   4
# ..                ...
# 166               163
# 167               164
# 168               165
# 169               166
# 170               167
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Δ Rank  \
# 0                                                                Full democracies
# 1                                                                             NaN
# 2                                                                             NaN
# 3                                                                             NaN
# 4                                                                             NaN
# ..                                                                            ...
# 166                                                                           NaN
# 167                                                                           NaN
# 168                                                                           NaN
# 169                                                                           NaN
# 170                                                                           NaN
#
#                               Country       Regime type     Overall score  \
# 0                    Full democracies  Full democracies  Full democracies
# 1                              Norway    Full democracy              9.81
# 2                             Iceland    Full democracy              9.37
# 3                              Sweden    Full democracy              9.26
# 4                         New Zealand    Full democracy              9.25
# ..                                ...               ...               ...
# 166                              Chad     Authoritarian              1.55
# 167                             Syria     Authoritarian              1.43
# 168          Central African Republic     Authoritarian              1.32
# 169  Democratic Republic of the Congo     Authoritarian              1.13
# 170                       North Korea     Authoritarian              1.08
#
#               Δ Score Elec­toral pro­cess and plura­lism  \
# 0    Full democracies                   Full democracies
# 1                0.06                              10.00
# 2                0.21                              10.00
# 3                0.13                               9.58
# 4                0.01                              10.00
# ..                ...                                ...
# 166              0.06                               0.00
# 167               NaN                               0.00
# 168               NaN                               1.25
# 169               NaN                               0.00
# 170               NaN                               0.00
#
#     Func­tioning of govern­ment Poli­tical partici­pation Poli­tical cul­ture  \
# 0              Full democracies          Full democracies    Full democracies
# 1                          9.64                     10.00               10.00
# 2                          8.57                      8.89               10.00
# 3                          9.29                      8.33               10.00
# 4                          8.93                      8.89                8.75
# ..                          ...                       ...                 ...
# 166                        0.00                      1.67                3.75
# 167                        0.00                      2.78                4.38
# 168                        0.00                      1.11                1.88
# 169                        0.00                      1.67                3.13
# 170                        2.50                      1.67                1.25
#
#      Civil liber­ties
# 0    Full democracies
# 1                9.41
# 2                9.41
# 3                9.12
# 4                9.71
# ..                ...
# 166              2.35
# 167              0.00
# 168              2.35
# 169              0.88
# 170              0.00
#
# [171 rows x 11 columns]

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.4.0-py2.py3-none-any.whl (65 kB)
# Requirement already satisfied: requests<3,>=2.11.1 in c:\users\john\anaconda3\lib\site-packages (from tweepy) (2.26.0)
# Collecting requests-oauthlib<2,>=1.0.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\john\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\john\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\john\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\john\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2021.10.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.1 requests-oauthlib-1.3.0 tweepy-4.4.0

# %%
import tweepy

# %%
# credentials
consumer_key = 'wygrepSAb42uydFw3vqvP7c1X'
consumer_secret ='wUmRPtCwOnPLCjdz19up0TLHxkZix1JrSIBIJcQG3cHqBe11f8'
access_token =  '1477830708785602567-NutgsL0rkDaIhaMEuUzaWXjnvwZuwB'
access_token_secret = 'm1B3tpRrOTJeMvDqA1IgCyrlllv2slxPEcWUDOuKUWU82'

# introducing myself:
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api=tweepy.API(auth, wait_on_rate_limit=True,timeout=60,
               parser=tweepy.parsers.JSONParser())

# %%
who='@Minsa_Peru'
howMany=20
gottenTweets = api.user_timeline(screen_name = who, 
                                 count = howMany, 
                                 include_rts = False,
                                 tweet_mode="extended")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7292/1256972986.py in <module>
#       1 who='@Minsa_Peru'
#       2 howMany=20
# ----> 3 gottenTweets = api.user_timeline(screen_name = who,
#       4                                  count = howMany,
#       5                                  include_rts = False,
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in user_timeline(self, **kwargs)
#     569         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-user_timeline
#     570         """
# --> 571         return self.request(
#     572             'GET', 'statuses/user_timeline', endpoint_parameters=(
#     573                 'user_id', 'screen_name', 'since_id', 'count', 'max_id',
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     257                 raise Unauthorized(resp)
#     258             if resp.status_code == 403:
# --> 259                 raise Forbidden(resp)
#     260             if resp.status_code == 404:
#     261                 raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have Essential access which includes access to Twitter API v2 endpoints only. If you need access to this endpoint, you’ll need to apply for Elevated access via the Developer Portal. You can learn more here: https://developer.twitter.com/en/docs/twitter-api/getting-started/about-twitter-api#v2-access-leve
